# %% [markdown]
# Capstone Project - Week 5

# %% [markdown]
# Construction of Hospitals Dependence on State County Demographic Data

# %% [markdown]
# NOTE: THE VERY LAST DATAFRAME SHOWN IN THIS NOTEBOOK SHOWS THE RESULTS THAT THIS PROJECT INTENDED TO ACHIEVE

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py36_0         149 KB  conda-forge
#     scikit-learn-0.20.1        |   py36h22eb022_0         5.7 MB
#     liblapack-3.8.0            |      11_openblas          10 KB  conda-forge
#     liblapacke-3.8.0           |      11_openblas          10 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     libopenblas-0.3.6          |       h5a2b251_2         7.7 MB
#     scipy-1.4.1                |   py36h921218d_0        18.9 MB  conda-forge
#     libcblas-3.8.0             |      11_openblas          10 KB  conda-forge
#     libblas-3.8.0              |      11_openblas          10 KB  conda-forge
#     numpy-1.17.5               |   py36h95a1406_0         5.2 MB  conda-forge
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     blas-2.11                  |         openblas          10 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        37.8 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0                              conda-forge
#     geopy:         1.20.0-py_0                            conda-forge
#     libblas:       3.8.0-11_openblas                      conda-forge
#     libcblas:      3.8.0-11_openblas                      conda-forge
#     liblapack:     3.8.0-11_openblas                      conda-forge
#     liblapacke:    3.8.0-11_openblas                      conda-forge
#     libopenblas:   0.3.6-h5a2b251_2
#
# The following packages will be UPDATED:
#
#     blas:          1.1-openblas                           conda-forge --> 2.11-openblas         conda-forge
#     certifi:       2019.9.11-py36_0                       conda-forge --> 2019.11.28-py36_0     conda-forge
#     numpy:         1.16.2-py36_blas_openblash1522bff_0    conda-forge [blas_openblas] --> 1.17.5-py36h95a1406_0 conda-forge
#     scipy:         1.2.1-py36_blas_openblash1522bff_0     conda-forge [blas_openblas] --> 1.4.1-py36h921218d_0  conda-forge
#
# The following packages will be DOWNGRADED:
#
#     scikit-learn:  0.20.1-py36_blas_openblashebff5e3_1200 conda-forge [blas_openblas] --> 0.20.1-py36h22eb022_0
#
#
# Downloading and Extracting Packages
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# scikit-learn-0.20.1  | 5.7 MB    | ##################################### | 100%
# liblapack-3.8.0      | 10 KB     | ##################################### | 100%
# liblapacke-3.8.0     | 10 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# libopenblas-0.3.6    | 7.7 MB    | ##################################### | 100%
# scipy-1.4.1          | 18.9 MB   | ##################################### | 100%
# libcblas-3.8.0       | 10 KB     | ##################################### | 100%
# libblas-3.8.0        | 10 KB     | ##################################### | 100%
# numpy-1.17.5         | 5.2 MB    | ##################################### | 100%
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# blas-2.11            | 10 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
# install lxml in order to get the wikipedia postal code table data
# !pip install lxml
# Out:
# Collecting lxml
#   Downloading https://files.pythonhosted.org/packages/68/30/affd16b77edf9537f5be051905f33527021e20d563d013e8c42c7fd01949/lxml-4.4.2-cp36-cp36m-manylinux1_x86_64.whl (5.8MB)
#      |████████████████████████████████| 5.8MB 7.6MB/s eta 0:00:01
# Installing collected packages: lxml
# Successfully installed lxml-4.4.2

# %%
# Pennsylvania County Name List, Income and Population (pa_cnty_list_1)
# Read in the table from the Web Page and then display sample contents of the dataframe
pa_cnty_list_1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_Pennsylvania_counties_by_per_capita_income",skiprows=0)[1]
pa_cnty_list_1.head()
# Out:
#    Rank      County Per capitaincome Medianhouseholdincome Medianfamilyincome  \
# 0   1.0     Chester          $41,251               $84,741           $101,760
# 1   2.0  Montgomery          $40,076               $76,380            $94,592
# 2   3.0       Bucks          $35,687               $74,828            $90,274
# 3   4.0    Delaware          $32,067               $61,876            $77,879
# 4   5.0  Cumberland          $30,119               $60,219            $75,000
#
#    Population  Number ofhouseholds
# 0      498886               182900
# 1      799874               307750
# 2      625249               234849
# 3      558979               208700
# 4      235406                93943

# %%
# Drop un-needed columns from dataframe: pa_cnty_list_1: 'Rank', 'Per capitaincome', 'Medianfamilyincome', 'Number ofhouseholds'
pa_cnty_list_1.drop(['Rank', 'Per capitaincome','Medianfamilyincome','Number ofhouseholds'], axis=1, inplace=True)
pa_cnty_list_1.head()
# Out:
#        County Medianhouseholdincome  Population
# 0     Chester               $84,741      498886
# 1  Montgomery               $76,380      799874
# 2       Bucks               $74,828      625249
# 3    Delaware               $61,876      558979
# 4  Cumberland               $60,219      235406

# %%
# Pennsylvania County Name List, Latitude & Longitude (pa_cnty_list_2)
# Read in the table from the CSV file and then display sample contents of the dataframe
pa_cnty_list_2 = pd.read_csv("PA_County_Latitude_Longitude.csv")
pa_cnty_list_2.head()
# Out:
#   County Name  County Code Number  County Code text  Longitude   Latitude  \
# 0       Adams                   1                 1 -77.222243  39.872096
# 1       Berks                   6                 6 -75.930773  40.419396
# 2     Cambria                  11                11 -78.718942  40.491275
# 3    Sullivan                  57                57 -76.514792  41.448099
# 4      Mercer                  43                43 -80.260094  41.302378
#
#            New Georeferenced Column
# 0  POINT (-77.22224271 39.87209565)
# 1  POINT (-75.93077327 40.41939635)
# 2  POINT (-78.71894174 40.49127491)
# 3    POINT (-76.5147922 41.4480994)
# 4  POINT (-80.26009411 41.30237777)

# %%
# Drop un-needed columns from dataframe: pa_cnty_list_2: 'County Code Number', 'County Code text', 'New Georeferenced Column' 
pa_cnty_list_2.drop(['County Code Number', 'County Code text','New Georeferenced Column'], axis=1, inplace=True)
pa_cnty_list_2.head()
# Out:
#   County Name  Longitude   Latitude
# 0       Adams -77.222243  39.872096
# 1       Berks -75.930773  40.419396
# 2     Cambria -78.718942  40.491275
# 3    Sullivan -76.514792  41.448099
# 4      Mercer -80.260094  41.302378

# %%
# Now combine (merge) the two dataframes into one dataframe called: pa_cnty_list_final
pa_cnty_list_final = pa_cnty_list_1.merge(pa_cnty_list_2, left_on=['County'], right_on=['County Name'])

# %%
# Display sample contents of the dataframe 'pa_cnty_list_final' after merging
pa_cnty_list_final.head()
# Out:
#        County Medianhouseholdincome  Population County Name  Longitude  \
# 0     Chester               $84,741      498886     Chester -75.756265
# 1  Montgomery               $76,380      799874  Montgomery -75.372520
# 2       Bucks               $74,828      625249       Bucks -75.112912
# 3    Delaware               $61,876      558979    Delaware -75.406277
# 4  Cumberland               $60,219      235406  Cumberland -77.268663
#
#     Latitude
# 0  39.974871
# 1  40.209899
# 2  40.335011
# 3  39.916579
# 4  40.167598

# %%
# Drop un-needed columns from dataframe: pa_cnty_list_final: 'County Name' 
pa_cnty_list_final.drop(['County Name'], axis=1, inplace=True)
pa_cnty_list_final.head()
# Out:
#        County Medianhouseholdincome  Population  Longitude   Latitude
# 0     Chester               $84,741      498886 -75.756265  39.974871
# 1  Montgomery               $76,380      799874 -75.372520  40.209899
# 2       Bucks               $74,828      625249 -75.112912  40.335011
# 3    Delaware               $61,876      558979 -75.406277  39.916579
# 4  Cumberland               $60,219      235406 -77.268663  40.167598

# %%
# Now, Re-order the columns in dataframe: 'pa_cnty_list_final'
pa_cnty_list_final = pa_cnty_list_final[['County', 'Medianhouseholdincome', 'Population', 'Latitude', 'Longitude']]

# %%
# Now display sample data from the dataframe after column re-ordering
pa_cnty_list_final.head()
# Out:
#        County Medianhouseholdincome  Population   Latitude  Longitude
# 0     Chester               $84,741      498886  39.974871 -75.756265
# 1  Montgomery               $76,380      799874  40.209899 -75.372520
# 2       Bucks               $74,828      625249  40.335011 -75.112912
# 3    Delaware               $61,876      558979  39.916579 -75.406277
# 4  Cumberland               $60,219      235406  40.167598 -77.268663

# %%
# Remove the dollar sign ($) from the column: 'Medianhouseholdincome'
pa_cnty_list_final['Medianhouseholdincome'] = pa_cnty_list_final['Medianhouseholdincome'].replace({'\$':''}, regex = True)

# Remove the comma (,) from the column: 'Medianhouseholdincome'
pa_cnty_list_final['Medianhouseholdincome'] = pa_cnty_list_final['Medianhouseholdincome'].replace({'\,':''}, regex = True)

# %%
# Show sample data from the dataframe - this is part of the source of the data needed for this project.
pa_cnty_list_final.head()
# Out:
#        County Medianhouseholdincome  Population   Latitude  Longitude
# 0     Chester                 84741      498886  39.974871 -75.756265
# 1  Montgomery                 76380      799874  40.209899 -75.372520
# 2       Bucks                 74828      625249  40.335011 -75.112912
# 3    Delaware                 61876      558979  39.916579 -75.406277
# 4  Cumberland                 60219      235406  40.167598 -77.268663

# %%
# Now, Display ALL of the dataframe data, but sorted by County.  This is being done just to make the dataframe data look more-organized, but is not a requirement.
pa_cnty_list_final.sort_values(['County'])
# Out:
#             County Medianhouseholdincome  Population   Latitude  Longitude
# 17           Adams                 56529      101407  39.872096 -77.222243
# 5        Allegheny                 47961     1223348  40.467355 -79.986198
# 36       Armstrong                 42752       68941  40.815095 -79.473169
# 22          Beaver                 46190      170539  40.683492 -80.351074
# 54         Bedford                 40249       49762  40.007375 -78.491165
# 19           Berks                 53470      411442  40.419396 -75.930773
# 29           Blair                 42363      127089  40.485550 -78.349077
# 48        Bradford                 40543       62622  41.791178 -76.518256
# 2            Bucks                 74828      625249  40.335011 -75.112912
# 6           Butler                 56878      183862  40.910832 -79.917118
# 44         Cambria                 39574      143679  40.491275 -78.718942
# 43         Cameron                 40733        5085  41.438803 -78.209169
# 27          Carbon                 47744       65249  40.919367 -75.711070
# 24          Centre                 47016      153990  40.919314 -77.825001
# 0          Chester                 84741      498886  39.974871 -75.756265
# 59         Clarion                 40028       39988  41.192791 -79.424836
# 61      Clearfield                 37130       81642  41.000429 -78.475583
# 64         Clinton                 39354       39238  41.232863 -77.642838
# 33        Columbia                 42788       67295  41.049121 -76.410022
# 56        Crawford                 38924       88765  41.685469 -80.113211
# 4       Cumberland                 60219      235406  40.167598 -77.268663
# 8          Dauphin                 52371      268100  40.419746 -76.779606
# 3         Delaware                 61876      558979  39.916579 -75.406277
# 30             Elk                 43745       31946  41.428194 -78.649477
# 31            Erie                 43595      280566  41.994138 -80.040759
# 65         Fayette                 34796      136606  39.919448 -79.651896
# 67          Forest                 35150        7716  41.513579 -79.237810
# 20        Franklin                 51035      149618  39.927862 -77.723988
# 39          Fulton                 45240       14845  39.924875 -78.114850
# 60          Greene                 40498       38686  39.854804 -80.229438
# 51      Huntingdon                 41700       45913  40.416105 -77.982766
# 53         Indiana                 40225       88880  40.652955 -79.093335
# 58       Jefferson                 38406       45200  41.131391 -79.001018
# 49         Juniata                 44276       24636  40.534330 -77.405775
# 23      Lackawanna                 43673      214437  41.439101 -75.612183
# 15       Lancaster                 54765      519445  40.045908 -76.251388
# 41        Lawrence                 42570       91108  40.993250 -80.337541
# 18         Lebanon                 52356      133568  40.367597 -76.461826
# 10          Lehigh                 53541      349497  40.614648 -75.600995
# 26         Luzerne                 42224      320918  41.178364 -75.991996
# 37        Lycoming                 42689      116111  41.344598 -77.069425
# 47          McKean                 40097       43450  41.810371 -78.571220
# 38          Mercer                 42573      116638  41.302378 -80.260094
# 66         Mifflin                 37539       46682  40.612749 -77.620031
# 21          Monroe                 56733      169842  41.060918 -75.340836
# 1       Montgomery                 76380      799874  40.209899 -75.372520
# 13         Montour                 45255       18267  41.028018 -76.664705
# 7      Northampton                 58762      297735  40.754595 -75.312637
# 50  Northumberland                 38387       94528  40.851509 -76.711884
# 12    Pennsylvania                 50398    12702379  39.346129 -75.167756
# 25           Perry                 52659       45969  40.404153 -77.259074
# 45    Philadelphia                 36251     1526006  40.004444 -75.140236
# 9             Pike                 56843       57369  41.332572 -75.032709
# 52          Potter                 39196       17457  41.744206 -77.898792
# 42      Schuylkill                 42315      148289  40.707512 -76.223324
# 46          Snyder                 44713       39702  40.771137 -77.072560
# 62        Somerset                 39194       77742  39.971463 -79.031002
# 63        Sullivan                 36250        6428  41.448099 -76.514792
# 34     Susquehanna                 43457       43356  41.820569 -75.802503
# 57           Tioga                 40338       41981  41.773338 -77.257881
# 40           Union                 45474       44947  40.964731 -77.064158
# 55         Venango                 39812       54984  41.403413 -79.762866
# 35          Warren                 41286       41815  41.816752 -79.278582
# 14      Washington                 49687      207820  40.191097 -80.251801
# 32           Wayne                 45930       52822  41.649698 -75.305154
# 16    Westmoreland                 47689      365169  40.310315 -79.471341
# 28         Wyoming                 47403       28276  41.518925 -76.018130
# 11            York                 57494      434972  39.921925 -76.725761

# %% [markdown]
# Use geopy library to get the latitude and longitude values of the Commonwealth of Pennsylvania.

# %%
# Define the user agent here
address = 'Pennsylvania'

geolocator = Nominatim(user_agent="pa_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinates of Pennsylvania are: {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinates of Pennsylvania are: 40.9699889, -77.7278831.

# %%
# create map of Pennsylvania using latitude and longitude values.   This will show the location points of all the 67 Pennsylvania Counties.
map_pa = folium.Map(location=[latitude, longitude], zoom_start=8)
    
# add markers to map
for  lat, lng, county, income, popl in zip(pa_cnty_list_final['Latitude'], pa_cnty_list_final['Longitude'], pa_cnty_list_final['County'], pa_cnty_list_final['Medianhouseholdincome'], pa_cnty_list_final['Population']):
    label = '{}'.format(county)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_pa)      
    
map_pa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the counties and segment them.

# %% [markdown]
# Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'GM24OWQ25PEZHAV3PLKTL5BHKRV25IVZ55G2YRHPM1TPIVY3' # your Foursquare ID
CLIENT_SECRET = '5TQSDFRDYQCALQGHJJI5TBGGUSNHF0KXRNML4NRIPW40MTQU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: GM24OWQ25PEZHAV3PLKTL5BHKRV25IVZ55G2YRHPM1TPIVY3
# CLIENT_SECRET:5TQSDFRDYQCALQGHJJI5TBGGUSNHF0KXRNML4NRIPW40MTQU

# %%
# Get the first Pennsylavania County name here
pa_cnty_list_final.loc[0, 'County']
# Out:
# 'Chester'

# %% [markdown]
# Get the county's latitude and longitude values.

# %%
# Get the county's latitude and longitude values.
county_latitude = pa_cnty_list_final.loc[0, 'Latitude'] # county latitude value
county_longitude = pa_cnty_list_final.loc[0, 'Longitude'] # county longitude value

county_name = pa_cnty_list_final.loc[0, 'County'] # county name

print('Latitude and longitude values of {} County are: {}, {}.'.format(county_name, 
                                                               county_latitude, 
                                                               county_longitude))
# Out:
# Latitude and longitude values of Chester County are: 39.97487056, -75.75626498.

# %% [markdown]
# Now, let's get the top 50 Urgent Care Centers that are in Chester County within a radius of 50 miles (or, 80,467 meters)

# %% [markdown]
# First, let's create the GET request URL. Name your URL url.

# %%
# Create the URL that will be used to get a list of Urgent Care Centers in Chester County
radius = 80467
LIMIT = 50
categoryId='56aa371be4b08b9a8d573526' # Urgent Care Center 
search_query = county_name
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, county_latitude, county_longitude, VERSION, radius, LIMIT, categoryId)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=GM24OWQ25PEZHAV3PLKTL5BHKRV25IVZ55G2YRHPM1TPIVY3&client_secret=5TQSDFRDYQCALQGHJJI5TBGGUSNHF0KXRNML4NRIPW40MTQU&ll=39.97487056,-75.75626498&v=20180605&radius=80467&limit=50&categoryId=56aa371be4b08b9a8d573526'

# %%
# Call the GET using the previously-created URL
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e2a634da2e538001b018ea0'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Current map view',
#   'headerFullLocation': 'Current map view',
#   'headerLocationGranularity': 'unknown',
#   'query': 'urgent care center',
#   'totalResults': 167,
#   'suggestedBounds': {'ne': {'lat': 40.699074284203725,
#     'lng': -74.81299634644621},
#    'sw': {'lat': 39.250666835796274, 'lng': -76.69953361355378}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2e69487cc0c9b62203ea9a',
#        'name': 'Patient First - Aberdeen',
#        'location': {'address': '995 Hospitality Way',
#         'lat': 39.52415940108369,
#         'lng': -76.18540018631576,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.52415940108369,
#           'lng': -76.18540018631576}],
#         'distance': 62179,
#         'postalCode': '21001',
#         'cc': 'US',
#         'city': 'Aberdeen',
#         'state': 'MD',
#         'country': 'United States',
#         'formattedAddress': ['995 Hospitality Way',
#          'Aberdeen, MD 21001',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2e69487cc0c9b62203ea9a-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cec0336934d8eec45905833',
#        'name': 'AFC Urgent Care Downingtown',
#        'location': {'address': '150 E Pennsylvania Ave Ste 140',
#         'lat': 40.0081268,
#         'lng': -75.7018851,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.0081268,
#           'lng': -75.7018851}],
#         'distance': 5934,
#         'postalCode': '19335',
#         'cc': 'US',
#         'city': 'Downingtown',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['150 E Pennsylvania Ave Ste 140',
#          'Downingtown, PA 19335',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '328000620'}},
#       'referralId': 'e-0-4cec0336934d8eec45905833-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '594423c7a4ba7c683f6ff20b',
#        'name': 'Patient First - Downingtown',
#        'location': {'address': '967 E. Lancaster Avenue',
#         'lat': 40.0177005,
#         'lng': -75.6810188,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.0177005,
#           'lng': -75.6810188}],
#         'distance': 7994,
#         'postalCode': '19335',
#         'cc': 'US',
#         'city': 'Downingtown',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['967 E. Lancaster Avenue',
#          'Downingtown, PA 19335',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-594423c7a4ba7c683f6ff20b-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c066fa4517d0f47b0f3f515',
#        'name': 'Premier Urgent Care',
#        'location': {'address': '278 Eagleview Blvd',
#         'lat': 40.055876,
#         'lng': -75.66744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.055876,
#           'lng': -75.66744}],
#         'distance': 11775,
#         'postalCode': '19341',
#         'cc': 'US',
#         'city': 'Exton',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['278 Eagleview Blvd',
#          'Exton, PA 19341',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c066fa4517d0f47b0f3f515-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f9ac4bfe4b0d8e6217f0ddc',
#        'name': 'Premier Urgent Care',
#        'location': {'address': '300 Old Forge Ln',
#         'lat': 39.862024,
#         'lng': -75.677863,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.862024,
#           'lng': -75.677863}],
#         'distance': 14234,
#         'postalCode': '19348',
#         'cc': 'US',
#         'city': 'Kennett Square',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['300 Old Forge Ln',
#          'Kennett Square, PA 19348',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f9ac4bfe4b0d8e6217f0ddc-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53bb040d498eff1991d40baa',
#        'name': 'Urgent Care',
#        'location': {'lat': 39.980063262310196,
#         'lng': -75.9306029459237,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.980063262310196,
#           'lng': -75.9306029459237}],
#         'distance': 14882,
#         'cc': 'US',
#         'state': 'Pennsylvania',
#         'country': 'United States',
#         'formattedAddress': ['Pennsylvania', 'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '365808489'}},
#       'referralId': 'e-0-53bb040d498eff1991d40baa-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fd39616e4b002c9e8102a99',
#        'name': 'Lancaster General Health Urgent Care',
#        'location': {'address': '950 S Octorara Trl',
#         'lat': 39.9801961,
#         'lng': -75.9310612,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9801961,
#           'lng': -75.9310612}],
#         'distance': 14922,
#         'postalCode': '19365',
#         'cc': 'US',
#         'city': 'Parkesburg',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['950 S Octorara Trl',
#          'Parkesburg, PA 19365',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '366808958'}},
#       'referralId': 'e-0-4fd39616e4b002c9e8102a99-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '593edb5386f4cc4a04e8cf86',
#        'name': 'Premier Care',
#        'location': {'lat': 40.041092,
#         'lng': -75.540596,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.041092,
#           'lng': -75.540596}],
#         'distance': 19811,
#         'postalCode': '19355',
#         'cc': 'US',
#         'city': 'Malvern',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['Malvern, PA 19355', 'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-593edb5386f4cc4a04e8cf86-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cf5a37a535d6f002c8793bd',
#        'name': 'Tower Health Urgent Care',
#        'location': {'address': '215 Lancaster Ave',
#         'lat': 40.041267,
#         'lng': -75.54037,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.041267,
#           'lng': -75.54037}],
#         'distance': 19836,
#         'postalCode': '19355',
#         'cc': 'US',
#         'city': 'Malvern',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['215 Lancaster Ave',
#          'Malvern, PA 19355',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5cf5a37a535d6f002c8793bd-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c13b23c7f7f2d7f2579df68',
#        'name': 'Hockessin Walk-In Medical Care',
#        'location': {'address': '316 Lantana Dr',
#         'lat': 39.773920000000004,
#         'lng': -75.70902,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.773920000000004,
#           'lng': -75.70902}],
#         'distance': 22730,
#         'postalCode': '19707',
#         'cc': 'US',
#         'city': 'Hockessin',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['316 Lantana Dr',
#          'Hockessin, DE 19707',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c13b23c7f7f2d7f2579df68-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfff3c27c5637047e54adf0',
#        'name': 'Naamans Medical Aid Unit',
#        'location': {'address': '3401 Brandywine Pkwy',
#         'crossStreet': 'at Naamans Rd',
#         'lat': 39.83003544266874,
#         'lng': -75.53390264511108,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.83003544266874,
#           'lng': -75.53390264511108}],
#         'distance': 24910,
#         'postalCode': '19803',
#         'cc': 'US',
#         'city': 'Wilmington',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['3401 Brandywine Pkwy (at Naamans Rd)',
#          'Wilmington, DE 19803',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfff3c27c5637047e54adf0-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '532da38f498ec9a188365e27',
#        'name': 'AFC Urgent Care Phoenixville',
#        'location': {'address': '265 Schuylkill Road',
#         'crossStreet': 'Township Line Road',
#         'lat': 40.1357,
#         'lng': -75.54141899999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.1357,
#           'lng': -75.54141899999999}],
#         'distance': 25605,
#         'postalCode': '19460',
#         'cc': 'US',
#         'city': 'Phoenixville',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['265 Schuylkill Road (Township Line Road)',
#          'Phoenixville, PA 19460',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '84562646'}},
#       'referralId': 'e-0-532da38f498ec9a188365e27-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '560323f9498e8a3add392a6a',
#        'name': 'Got A Doc',
#        'location': {'address': '2105 Concord Pike',
#         'lat': 39.789703,
#         'lng': -75.54535600000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.789703,
#           'lng': -75.54535600000001}],
#         'distance': 27376,
#         'cc': 'US',
#         'city': 'Wilmington',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['2105 Concord Pike',
#          'Wilmington, DE',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-560323f9498e8a3add392a6a-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50b3b400498eee01f383ec33',
#        'name': 'MedExpress Walk-In Care',
#        'location': {'address': '3926 Kirkwood Highway',
#         'crossStreet': 'at Farrand Dr',
#         'lat': 39.728371169891766,
#         'lng': -75.64826667308807,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.728371169891766,
#           'lng': -75.64826667308807}],
#         'distance': 28950,
#         'postalCode': '19808',
#         'cc': 'US',
#         'neighborhood': 'Marshal',
#         'city': 'Wilmington',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['3926 Kirkwood Highway (at Farrand Dr)',
#          'Wilmington, DE 19808',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50b3b400498eee01f383ec33-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57c4b46f498ec95b5261a30b',
#        'name': 'Patient First - Devon',
#        'location': {'address': '133 Lancaster Avenue',
#         'lat': 40.046757,
#         'lng': -75.421978,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.046757,
#           'lng': -75.421978}],
#         'distance': 29603,
#         'postalCode': '19333',
#         'cc': 'US',
#         'city': 'Devon',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['133 Lancaster Avenue',
#          'Devon, PA 19333',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57c4b46f498ec95b5261a30b-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '581baaaf7c74e15859b18865',
#        'name': 'AFC Urgent Care Aston',
#        'location': {'address': '5024 Pennell Road',
#         'lat': 39.866821,
#         'lng': -75.427805,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.866821,
#           'lng': -75.427805}],
#         'distance': 30512,
#         'postalCode': '19014',
#         'cc': 'US',
#         'city': 'Aston',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['5024 Pennell Road',
#          'Aston, PA 19014',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-581baaaf7c74e15859b18865-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5f32f4832fa5935201edd3',
#        'name': 'Premier Urgent Care',
#        'location': {'address': '450 cresson blvd',
#         'lat': 40.131362261929986,
#         'lng': -75.45029346506412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.131362261929986,
#           'lng': -75.45029346506412}],
#         'distance': 31355,
#         'cc': 'US',
#         'city': 'Oaks',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['450 cresson blvd', 'Oaks, PA', 'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5f32f4832fa5935201edd3-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53126c6711d2c75d4ff4edf2',
#        'name': 'Patient First - Pottstown',
#        'location': {'address': '119 Shoemaker Road',
#         'lat': 40.251184,
#         'lng': -75.660499,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.251184,
#           'lng': -75.660499}],
#         'distance': 31821,
#         'postalCode': '19464',
#         'cc': 'US',
#         'city': 'Pottstown',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['119 Shoemaker Road',
#          'Pottstown, PA 19464',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53126c6711d2c75d4ff4edf2-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c40a876ff711b8d29ba1005',
#        'name': 'Tower Health Urgent Care',
#        'location': {'address': '1139 Ben Franklin Hwy W',
#         'lat': 40.2617368268966,
#         'lng': -75.73008786452071,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.2617368268966,
#           'lng': -75.73008786452071}],
#         'distance': 32011,
#         'postalCode': '19518',
#         'cc': 'US',
#         'city': 'Douglassville',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['1139 Ben Franklin Hwy W',
#          'Douglassville, PA 19518',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c40a876ff711b8d29ba1005-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '594a9d42419a9e5ea4aa3ee1',
#        'name': 'Patient First - Collegeville',
#        'location': {'address': '1411 S. Collegeville Road',
#         'lat': 40.166697212587344,
#         'lng': -75.47339634118744,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.166697212587344,
#           'lng': -75.47339634118744}],
#         'distance': 32196,
#         'postalCode': '19426',
#         'cc': 'US',
#         'city': 'Collegeville',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['1411 S. Collegeville Road',
#          'Collegeville, PA 19426',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-594a9d42419a9e5ea4aa3ee1-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc71fad15a7ef3bf1c078da',
#        'name': 'Concentra Urgent Care',
#        'location': {'address': '4110 Ogletown Stanton Rd',
#         'lat': 39.68554938707962,
#         'lng': -75.68437274547023,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.68554938707962,
#           'lng': -75.68437274547023}],
#         'distance': 32788,
#         'postalCode': '19713',
#         'cc': 'US',
#         'city': 'Newark',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['4110 Ogletown Stanton Rd',
#          'Newark, DE 19713',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc71fad15a7ef3bf1c078da-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '541f404f498e7ac704347f17',
#        'name': 'Premier Urgent Care',
#        'location': {'address': '635 Conestoga Rd',
#         'lat': 40.030564,
#         'lng': -75.363989,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.030564,
#           'lng': -75.363989}],
#         'distance': 34019,
#         'postalCode': '19085',
#         'cc': 'US',
#         'city': 'Villanova',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['635 Conestoga Rd',
#          'Villanova, PA 19085',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-541f404f498e7ac704347f17-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c51b98c9426c928663d4174',
#        'name': 'Premier Urgent Care',
#        'location': {'address': 'Ridge Pike',
#         'crossStreet': 'Tonwship Line',
#         'lat': 40.216325328134815,
#         'lng': -75.50321861603292,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.216325328134815,
#           'lng': -75.50321861603292}],
#         'distance': 34449,
#         'cc': 'US',
#         'city': 'Royersford',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['Ridge Pike (Tonwship Line)',
#          'Royersford, PA',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c51b98c9426c928663d4174-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5deef47cc02d88000703a09d',
#        'name': 'ChristianaCare Medical Aid Unit at STAR Campus',
#        'location': {'address': '550 South College Avenue 115',
#         'lat': 39.6640052,
#         'lng': -75.7532444,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.6640052,
#           'lng': -75.7532444}],
#         'distance': 34606,
#         'postalCode': '19713',
#         'cc': 'US',
#         'city': 'Newark',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['550 South College Avenue 115',
#          'Newark, DE 19713',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5deef47cc02d88000703a09d-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5deef42516b49c000800c614',
#        'name': 'ChristianaCare Medical Aid Unit at STAR Campus Pediatrics',
#        'location': {'address': '550 South College Avenue 115',
#         'lat': 39.6640052,
#         'lng': -75.7532444,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.6640052,
#           'lng': -75.7532444}],
#         'distance': 34606,
#         'postalCode': '19713',
#         'cc': 'US',
#         'city': 'Newark',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['550 South College Avenue 115',
#          'Newark, DE 19713',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5deef42516b49c000800c614-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '569eb100498e0f5f0910b7d2',
#        'name': 'Urgent Care',
#        'location': {'address': 'Lawrence Rd',
#         'crossStreet': 'at Crozer Keystone At Broomall',
#         'lat': 39.97581625669139,
#         'lng': -75.33856748230224,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.97581625669139,
#           'lng': -75.33856748230224}],
#         'distance': 35632,
#         'cc': 'US',
#         'city': 'Broomall',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['Lawrence Rd (at Crozer Keystone At Broomall)',
#          'Broomall, PA',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-569eb100498e0f5f0910b7d2-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50bfcceae4b0e418ed734833',
#        'name': 'MedExpress Walk-In Care',
#        'location': {'address': '129 N Dupont Highway',
#         'lat': 39.67231749562576,
#         'lng': -75.59898912906641,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.67231749562576,
#           'lng': -75.59898912906641}],
#         'distance': 36264,
#         'postalCode': '19720',
#         'cc': 'US',
#         'city': 'New Castle',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['129 N Dupont Highway',
#          'New Castle, DE 19720',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50bfcceae4b0e418ed734833-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dc40888ae608779d1169849',
#        'name': 'Valley Forge Urgent Care',
#        'location': {'address': '2521 W Main St',
#         'lat': 40.141331,
#         'lng': -75.387677,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.141331,
#           'lng': -75.387677}],
#         'distance': 36463,
#         'postalCode': '19403',
#         'cc': 'US',
#         'city': 'Norristown',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['2521 W Main St',
#          'Norristown, PA 19403',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dc40888ae608779d1169849-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f0f5a7577166a9deb7a32d7',
#        'name': 'careSTAT urgent care',
#        'location': {'address': '1305 W Chester Pike',
#         'crossStreet': 'at Manoa Shopping Center',
#         'lat': 39.97367634579674,
#         'lng': -75.32107765511482,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.97367634579674,
#           'lng': -75.32107765511482}],
#         'distance': 37124,
#         'postalCode': '19083',
#         'cc': 'US',
#         'city': 'Havertown',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['1305 W Chester Pike (at Manoa Shopping Center)',
#          'Havertown, PA 19083',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f0f5a7577166a9deb7a32d7-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53ced198498e640761faae98',
#        'name': 'Patient First - Springfield',
#        'location': {'address': '417 Baltimore Pike',
#         'lat': 39.921088011738355,
#         'lng': -75.32182011782265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.921088011738355,
#           'lng': -75.32182011782265}],
#         'distance': 37555,
#         'postalCode': '19064',
#         'cc': 'US',
#         'city': 'Springfield',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['417 Baltimore Pike',
#          'Springfield, PA 19064',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53ced198498e640761faae98-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5286bf3711d24eb2efb434b4',
#        'name': 'CareSTAT Urgent Care',
#        'location': {'address': '213 Morton Ave',
#         'lat': 39.884594,
#         'lng': -75.33064499999999,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.884594,
#           'lng': -75.33064499999999}],
#         'distance': 37696,
#         'postalCode': '19033',
#         'cc': 'US',
#         'city': 'Folsom',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['213 Morton Ave',
#          'Folsom, PA 19033',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5286bf3711d24eb2efb434b4-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a9871c70123587953e42fec',
#        'name': 'AFC Urgent Care Havertown',
#        'location': {'address': '115 W Eagle Rd',
#         'lat': 39.985285,
#         'lng': -75.314208,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.985285,
#           'lng': -75.314208}],
#         'distance': 37725,
#         'postalCode': '19083',
#         'cc': 'US',
#         'city': 'Havertown',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['115 W Eagle Rd',
#          'Havertown, PA 19083',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5a9871c70123587953e42fec-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55f9959f498e2b748d5b6842',
#        'name': 'ExpressCare Walk-In Medical Center',
#        'location': {'address': '1011 E Songsmith Dr',
#         'lat': 39.635469,
#         'lng': -75.657145,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.635469,
#           'lng': -75.657145}],
#         'distance': 38720,
#         'postalCode': '19701',
#         'cc': 'US',
#         'city': 'Bear',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['1011 E Songsmith Dr',
#          'Bear, DE 19701',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55f9959f498e2b748d5b6842-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e7ce7e6e5fa86288e7293e8',
#        'name': 'Quick Care—Tower Health Medical Group',
#        'location': {'address': '3703 Perkiomen Ave',
#         'lat': 40.317539816427356,
#         'lng': -75.87222826862184,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.317539816427356,
#           'lng': -75.87222826862184}],
#         'distance': 39401,
#         'postalCode': '19606',
#         'cc': 'US',
#         'neighborhood': 'Exeter Township',
#         'city': 'Reading',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['3703 Perkiomen Ave',
#          'Reading, PA 19606',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e7ce7e6e5fa86288e7293e8-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fc0d5aee4b03f9cf97f5eca',
#        'name': 'Lancaster General Health Urgent Care',
#        'location': {'address': '895 E Main St',
#         'lat': 40.16286025361296,
#         'lng': -76.15326762199402,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.16286025361296,
#           'lng': -76.15326762199402}],
#         'distance': 39771,
#         'postalCode': '17522',
#         'cc': 'US',
#         'city': 'Ephrata',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['895 E Main St',
#          'Ephrata, PA 17522',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '365308120'}},
#       'referralId': 'e-0-4fc0d5aee4b03f9cf97f5eca-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59dd4b17fe37402d70c6e623',
#        'name': 'ChristianaCare Medical Aid Unit at Glasgow',
#        'location': {'address': '2600 Glasgow Avenue',
#         'lat': 39.599205,
#         'lng': -75.744514,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.599205,
#           'lng': -75.744514}],
#         'distance': 41830,
#         'postalCode': '19702',
#         'cc': 'US',
#         'city': 'Newark',
#         'state': 'DE',
#         'country': 'United States',
#         'formattedAddress': ['2600 Glasgow Avenue',
#          'Newark, DE 19702',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59dd4b17fe37402d70c6e623-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '513a0bd5e4b01171b79df7e0',
#        'name': 'Patient First - East Norriton',
#        'location': {'address': '400 East Germantown Pike',
#         'lat': 40.13765279326856,
#         'lng': -75.3074798284421,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.13765279326856,
#           'lng': -75.3074798284421}],
#         'distance': 42314,
#         'postalCode': '19401',
#         'cc': 'US',
#         'city': 'East Norriton',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['400 East Germantown Pike',
#          'East Norriton, PA 19401',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-513a0bd5e4b01171b79df7e0-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c930a0cc53093002c6860cc',
#        'name': 'ExpressCare Urgent Care Center Elkton',
#        'location': {'address': '310 E Pulaski Hwy',
#         'lat': 39.5968851,
#         'lng': -75.8183952,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.5968851,
#           'lng': -75.8183952}],
#         'distance': 42411,
#         'postalCode': '21921',
#         'cc': 'US',
#         'city': 'Elkton',
#         'state': 'MD',
#         'country': 'United States',
#         'formattedAddress': ['310 E Pulaski Hwy',
#          'Elkton, MD 21921',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '537441942'}},
#       'referralId': 'e-0-5c930a0cc53093002c6860cc-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4fae9561e4b0d39d5317d8b8',
#        'name': 'ExpressCare Of Elkton',
#        'location': {'address': '310 E Pulaski Hwy',
#         'crossStreet': 'White Hall Rd.',
#         'lat': 39.596864000000004,
#         'lng': -75.818383,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.596864000000004,
#           'lng': -75.818383}],
#         'distance': 42413,
#         'postalCode': '21921',
#         'cc': 'US',
#         'city': 'Elkton',
#         'state': 'MD',
#         'country': 'United States',
#         'formattedAddress': ['310 E Pulaski Hwy (White Hall Rd.)',
#          'Elkton, MD 21921',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4fae9561e4b0d39d5317d8b8-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5329b507498ea5eaa7abcda7',
#        'name': 'AFC Urgent Care Narberth',
#        'location': {'address': '934 Montgomery Ave',
#         'lat': 40.01153,
#         'lng': -75.26093,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.01153,
#           'lng': -75.26093}],
#         'distance': 42440,
#         'postalCode': '19072',
#         'cc': 'US',
#         'city': 'Narberth',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['934 Montgomery Ave',
#          'Narberth, PA 19072',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '331250337'}},
#       'referralId': 'e-0-5329b507498ea5eaa7abcda7-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc47461920eb713d7b91e2c',
#        'name': 'Concentra Urgent Care',
#        'location': {'address': '850 Germantown Pike',
#         'lat': 40.12650173262047,
#         'lng': -75.29475688934332,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.12650173262047,
#           'lng': -75.29475688934332}],
#         'distance': 42795,
#         'postalCode': '19462',
#         'cc': 'US',
#         'city': 'Plymouth Meeting',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['850 Germantown Pike',
#          'Plymouth Meeting, PA 19462',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc47461920eb713d7b91e2c-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '551589ed498ef06e96c8b198',
#        'name': 'Premier Urgent Care',
#        'location': {'address': '580 W Germantown Pike',
#         'lat': 40.117238,
#         'lng': -75.28491600000001,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.117238,
#           'lng': -75.28491600000001}],
#         'distance': 43180,
#         'postalCode': '19462',
#         'cc': 'US',
#         'city': 'Plymouth Meeting',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['580 W Germantown Pike',
#          'Plymouth Meeting, PA 19462',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-551589ed498ef06e96c8b198-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c766dcbcad1b6002c46ba57',
#        'name': 'CityLife Health',
#        'location': {'address': '6232 Market St',
#         'lat': 39.96134940667086,
#         'lng': -75.24526476860046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.96134940667086,
#           'lng': -75.24526476860046}],
#         'distance': 43621,
#         'postalCode': '19139',
#         'cc': 'US',
#         'city': 'Philadelphia',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['6232 Market St',
#          'Philadelphia, PA 19139',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5c766dcbcad1b6002c46ba57-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8b62ae401a224b12a5b518',
#        'name': 'Urgent Care Center',
#        'location': {'address': '1661 Old Philadelphia Pike',
#         'lat': 40.03933226,
#         'lng': -76.26628388,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.03933226,
#           'lng': -76.26628388}],
#         'distance': 44075,
#         'postalCode': '17602',
#         'cc': 'US',
#         'city': 'Lancaster',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['1661 Old Philadelphia Pike',
#          'Lancaster, PA 17602',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8b62ae401a224b12a5b518-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '56ed757c498e6e5cb08b993d',
#        'name': 'Reading Health system urgent care',
#        'location': {'lat': 40.338898,
#         'lng': -75.963698,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.338898,
#           'lng': -75.963698}],
#         'distance': 44199,
#         'cc': 'US',
#         'city': 'Wyomissing',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['Wyomissing, PA', 'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-56ed757c498e6e5cb08b993d-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5575b269498ee891c1f546d6',
#        'name': 'Advanced Urgent Care',
#        'location': {'lat': 39.998284000000005,
#         'lng': -75.231654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.998284000000005,
#           'lng': -75.231654}],
#         'distance': 44820,
#         'cc': 'US',
#         'state': 'Pennsylvania',
#         'country': 'United States',
#         'formattedAddress': ['Pennsylvania', 'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5575b269498ee891c1f546d6-45'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '53a5d61a498e15614655dc79',
#        'name': 'Inspira Urgent Care Woolwich',
#        'location': {'address': '101 Lexington Rd Ste 530',
#         'lat': 39.739134,
#         'lng': -75.326425,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.739134,
#           'lng': -75.326425}],
#         'distance': 45142,
#         'postalCode': '08085',
#         'cc': 'US',
#         'city': 'Woolwich Township',
#         'state': 'NJ',
#         'country': 'United States',
#         'formattedAddress': ['101 Lexington Rd Ste 530',
#          'Woolwich Township, NJ 08085',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-53a5d61a498e15614655dc79-46'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5896531bb3cdc863e94487c5',
#        'name': 'premier urgent care',
#        'location': {'address': '2231 Bryn Mawr Ave',
#         'lat': 39.991769,
#         'lng': -75.226128,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.991769,
#           'lng': -75.226128}],
#         'distance': 45257,
#         'postalCode': '19131',
#         'cc': 'US',
#         'city': 'Philadelphia',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['2231 Bryn Mawr Ave',
#          'Philadelphia, PA 19131',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5896531bb3cdc863e94487c5-47'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5795fe43498e2ae71082c48e',
#        'name': 'Express Care Roxborough Memorial Urgent Care',
#        'location': {'address': '8500 Henry Ave',
#         'lat': 40.06307948503175,
#         'lng': -75.23750245571136,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.06307948503175,
#           'lng': -75.23750245571136}],
#         'distance': 45302,
#         'postalCode': '19128',
#         'cc': 'US',
#         'city': 'Philadelphia',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['8500 Henry Ave',
#          'Philadelphia, PA 19128',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5795fe43498e2ae71082c48e-48'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb734668db0a1434c107016',
#        'name': 'Concentra Urgent Care',
#        'location': {'address': '7000 Holstein Ave',
#         'lat': 39.9034595,
#         'lng': -75.2264592,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 39.9034595,
#           'lng': -75.2264592}],
#         'distance': 45912,
#         'postalCode': '19153',
#         'cc': 'US',
#         'city': 'Philadelphia',
#         'state': 'PA',
#         'country': 'United States',
#         'formattedAddress': ['7000 Holstein Ave',
#          'Philadelphia, PA 19153',
#          'United States']},
#        'categories': [{'id': '56aa371be4b08b9a8d573526',
#          'name': 'Urgent Care Center',
#          'pluralName': 'Urgent Care Centers',
#          'shortName': 'Urgent Care Center',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb734668db0a1434c107016-49'}]}]}}

# %%
# define a function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# Use this block of code to get a list of the Urgent Care Centers and then display a sample of them
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.head()
# Out:
#                           name          categories        lat        lng
# 0     Patient First - Aberdeen  Urgent Care Center  39.524159 -76.185400
# 1  AFC Urgent Care Downingtown  Urgent Care Center  40.008127 -75.701885
# 2  Patient First - Downingtown  Urgent Care Center  40.017700 -75.681019
# 3          Premier Urgent Care  Urgent Care Center  40.055876 -75.667440
# 4          Premier Urgent Care  Urgent Care Center  39.862024 -75.677863

# %%
# Show how many venues were returned by using the Foursquare API
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 50 venues were returned by Foursquare.

# %% [markdown]
# Let's create a function to repeat the same process to all the Counties in Pennsylvania

# %%
# Define a function that will process ALL the Counties in Pennsylvania
def getNearbyHospitals(names, latitudes, longitudes, radius=80467, categoryId='56aa371be4b08b9a8d573526'):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            categoryId)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['County', 
                  'County Latitude', 
                  'County Longitude', 
                  'Hospital', 
                  'Hospital Latitude', 
                  'Hospital Longitude', 
                  'Hospital Category']
    
    return(nearby_venues)

# %%
# Now write the code to run the above function on each county and create a new dataframe called pa_counties.
pa_counties = getNearbyHospitals(names=pa_cnty_list_final['County'],
                                   latitudes=pa_cnty_list_final['Latitude'],
                                   longitudes=pa_cnty_list_final['Longitude']
                                  )
# Out:
# Chester
# Montgomery
# Bucks
# Delaware
# Cumberland
# Allegheny
# Butler
# Northampton
# Dauphin
# Pike
# Lehigh
# York
# Pennsylvania
# Montour
# Washington
# Lancaster
# Westmoreland
# Adams
# Lebanon
# Berks
# Franklin
# Monroe
# Beaver
# Lackawanna
# Centre
# Perry
# Luzerne
# Carbon
# Wyoming
# Blair
# Elk
# Erie
# Wayne
# Columbia
# Susquehanna
# Warren
# Armstrong
# Lycoming
# Mercer
# Fulton
# Union
# Lawrence
# Schuylkill
# Cameron
# Cambria
# Philadelphia
# Snyder
# McKean
# Bradford
# Juniata
# Northumberland
# Huntingdon
# Potter
# Indiana
# Bedford
# Venango
# Crawford
# Tioga
# Jefferson
# Clarion
# Greene
# Clearfield
# Somerset
# Sullivan
# Clinton
# Fayette
# Mifflin
# Forest

# %%
# Now display the size of the dataframe that contains ALL the Urgent Care Centers, plus a sample list of the Urgent Care Centers in that dataframe
print(pa_counties.shape)
pa_counties.head()
# Out:
# (1831, 7)
#     County  County Latitude  County Longitude                     Hospital  \
# 0  Chester        39.974871        -75.756265     Patient First - Aberdeen
# 1  Chester        39.974871        -75.756265  AFC Urgent Care Downingtown
# 2  Chester        39.974871        -75.756265  Patient First - Downingtown
# 3  Chester        39.974871        -75.756265          Premier Urgent Care
# 4  Chester        39.974871        -75.756265          Premier Urgent Care
#
#    Hospital Latitude  Hospital Longitude   Hospital Category
# 0          39.524159          -76.185400  Urgent Care Center
# 1          40.008127          -75.701885  Urgent Care Center
# 2          40.017700          -75.681019  Urgent Care Center
# 3          40.055876          -75.667440  Urgent Care Center
# 4          39.862024          -75.677863  Urgent Care Center

# %%
# Get a count of the number of Urgent Care Centers in each County here then show a sample listing
pa_counties_cnt = pa_counties.groupby('County').count()
pa_counties_cnt.head()
# Out:
#            County Latitude  County Longitude  Hospital  Hospital Latitude  \
# County
# Adams                   50                50        50                 50
# Allegheny               40                40        40                 40
# Armstrong               38                38        38                 38
# Beaver                  43                43        43                 43
# Bedford                 14                14        14                 14
#
#            Hospital Longitude  Hospital Category
# County
# Adams                      50                 50
# Allegheny                  40                 40
# Armstrong                  38                 38
# Beaver                     43                 43
# Bedford                    14                 14

# %%
# Reset the dataframe index and then show a sample listing again
pa_counties_cnt = pa_counties_cnt.reset_index()
pa_counties_cnt.head()
# Out:
#       County  County Latitude  County Longitude  Hospital  Hospital Latitude  \
# 0      Adams               50                50        50                 50
# 1  Allegheny               40                40        40                 40
# 2  Armstrong               38                38        38                 38
# 3     Beaver               43                43        43                 43
# 4    Bedford               14                14        14                 14
#
#    Hospital Longitude  Hospital Category
# 0                  50                 50
# 1                  40                 40
# 2                  38                 38
# 3                  43                 43
# 4                  14                 14

# %%
# Pull into a new dataframe the County Name along with its Urgent Care Center count (the 'County Latitude' column will hold the count for now)
hosp_count = pa_counties_cnt.loc[:,'County':'County Latitude']

# %%
# Display a sample of the Pennsylvania Counties along with their Urgent Care Center count
hosp_count.head()
# Out:
#       County  County Latitude
# 0      Adams               50
# 1  Allegheny               40
# 2  Armstrong               38
# 3     Beaver               43
# 4    Bedford               14

# %%
# Rename the incorrect 'County Latitude' column name to be 'CenterCount'
hosp_count.rename(columns = {'County Latitude':'CenterCount'}, inplace = True)

# %%
# Display a small sample from the dataframe with the corrected column name
hosp_count.head()
# Out:
#       County  CenterCount
# 0      Adams           50
# 1  Allegheny           40
# 2  Armstrong           38
# 3     Beaver           43
# 4    Bedford           14

# %%
# Save a copy of the 'hosp_count' dataframe in case we need to recover it later
hosp_count_save = hosp_count

# %%
# Now combine (merge) the two dataframes into one dataframe called: pa_cnty_list_final2
pa_cnty_demog = hosp_count.merge(pa_cnty_list_final, left_on=['County'], right_on=['County'])

# %%
# Display a small sample of the new 'pa_cnty_demog' dataframe.
# THIS IS THE DATAFRAME THAT WILL BE USED TO DETERMINE IF THE INVESTORS WILL BUILD NEW FOR-PROFIT URGENT CARE CENTERS IN ANY OF THE COUNTIES.
# THE DECISION TO BUILD WILL BE BASED ON CRITERIA IN THE NEXT CODE BLOCK
pa_cnty_demog.head()
# Out:
#       County  CenterCount Medianhouseholdincome  Population   Latitude  \
# 0      Adams           50                 56529      101407  39.872096
# 1  Allegheny           40                 47961     1223348  40.467355
# 2  Armstrong           38                 42752       68941  40.815095
# 3     Beaver           43                 46190      170539  40.683492
# 4    Bedford           14                 40249       49762  40.007375
#
#    Longitude
# 0 -77.222243
# 1 -79.986198
# 2 -79.473169
# 3 -80.351074
# 4 -78.491165

# %%
# Now we need to determine what Counties the Investors would want to build new for-profit Urgent Care Centers based on the following criteria:
# 
#      Existing Urgent Care Centers in a County:  Ten (10) or Less
#      Total County Population:                   30,000 people or more
#      Median Household Income in a County:       $40,000 or more
#
# Apply the following criteria to the 'pa_cnty_list_final2' dataframe to get the prospective county name list:
#
# Filter: Number of Existing Urgent Care Centers:  Must be Ten (10) or Less
centerLE10 =  pa_cnty_demog['CenterCount']<=10
pa_cnty_demog2 = pa_cnty_demog[centerLE10]

# Filter: Total County Population:       Must be at least 30,000 people or more
poplGE30k =  pa_cnty_demog2['Population']>=30000
pa_cnty_demog3 = pa_cnty_demog2[poplGE30k]

# Filter: Median Household Income:       Must be at least $40,000 or more
pa_cnty_demog3["Medianhouseholdincome"] = pd.to_numeric(pa_cnty_demog3["Medianhouseholdincome"])

incGE40k =  pa_cnty_demog3['Medianhouseholdincome']>=40000
pa_cnty_demog4 = pa_cnty_demog3[incGE40k]

# NOTICE: THE RESULTING 'WARNING' MESSAGE WILL NOT FAIL THE NOTEBOOK OR THE OUTCOME OF THIS PROJECT.
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Now display ALL the Counties that meet the Investor's criteria.   These are the Counties that the investors plan to build new for-profit Urgent Care Centers
# WE ACCOMPLISHED THE GOAL AT THIS POINT IN DETERMINING THE COUNTIES THAT THE INVESTORS PLAN TO BUILD THEIR NEW FOR-PROFIT URGENT CARE CENTERS IN.
# THE COUNTY LIST IS SHOWN BELOW.  (The CenterCount column shown below is the count of 'already-existing' Urgent Care Centers in a particular County)
pa_cnty_demog4
# Out:
#         County  CenterCount  Medianhouseholdincome  Population   Latitude  \
# 6        Blair            9                  42363      127089  40.485550
# 13      Centre            5                  47016      153990  40.919314
# 15     Clarion            7                  40028       39988  41.192791
# 23         Elk            2                  43745       31946  41.428194
# 30  Huntingdon           10                  41700       45913  40.416105
# 40    Lycoming            3                  42689      116111  41.344598
# 41      McKean            4                  40097       43450  41.810371
# 59       Tioga            4                  40338       41981  41.773338
#
#     Longitude
# 6  -78.349077
# 13 -77.825001
# 15 -79.424836
# 23 -78.649477
# 30 -77.982766
# 40 -77.069425
# 41 -78.571220
# 59 -77.257881

# %%
# display the size of the resulting dataframe
print(pa_cnty_demog4.shape)
# Out:
# (8, 6)

# %%
# THIS CONCLUDES THE ANALYSIS FOR CAPSTONE PROJECT OF WEEK 5 #

# %%
# Construction of Hospitals Dependence on State County Demographic Data
